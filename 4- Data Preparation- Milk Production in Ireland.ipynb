# %% [markdown]
# # Data Preparation (Milk Production in Ireland)

# %% [markdown]
# #### This section aims to study the milk production and utilisation (in million litres) from the farms of Ireland.

# %% [markdown]
# #### <font color=red>*Here, the data will be cleaned by removing unnecessary columns.*</font>

# %%
#Importing Libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Ireland_Milk_Production.csv')

# %%
df
# Out:
#         Month  Year  Amount            Unit
# 0     January  2020   176.2  million litres
# 1    February  2020   331.7  million litres
# 2       March  2020   725.7  million litres
# 3       April  2020   982.7  million litres
# 4         May  2020  1115.3  million litres
# 5        June  2020  1031.0  million litres
# 6        July  2020   985.0  million litres
# 7      August  2020   867.6  million litres
# 8   September  2020   725.4  million litres
# 9     October  2020   646.8  million litres
# 10   November  2020   449.8  million litres
# 11   December  2020   258.8  million litres
# 12    January  2021   182.2  million litres
# 13   February  2021   352.4  million litres
# 14      March  2021   829.7  million litres
# 15      April  2021  1060.5  million litres
# 16        May  2021  1181.0  million litres
# 17       June  2021  1067.3  million litres
# 18       July  2021  1017.3  million litres
# 19     August  2021   917.4  million litres
# 20  September  2021   776.7  million litres
# 21    October  2021   649.6  million litres
# 22   November  2021   465.9  million litres
# 23   December  2021   258.5  million litres
# 24    January  2022   183.3  million litres
# 25   February  2022   367.5  million litres
# 26      March  2022   808.6  million litres
# 27      April  2022  1054.6  million litres
# 28        May  2022  1166.0  million litres
# 29       June  2022  1057.6  million litres
# 30       July  2022  1022.8  million litres
# 31     August  2022   919.0  million litres
# 32  September  2022   785.6  million litres
# 33    October  2022   698.5  million litres

# %% [markdown]
# <font color=red>The column 'Unit' will be removed so that the column will not be included when the data is melted and pivoted making to create a less messy new data.</font>

# %%
to_drop = ['Unit']
df.drop(to_drop, inplace=True, axis=1)

# %%
df.shape
# Out:
# (34, 3)

# %%
df
# Out:
#         Month  Year  Amount
# 0     January  2020   176.2
# 1    February  2020   331.7
# 2       March  2020   725.7
# 3       April  2020   982.7
# 4         May  2020  1115.3
# 5        June  2020  1031.0
# 6        July  2020   985.0
# 7      August  2020   867.6
# 8   September  2020   725.4
# 9     October  2020   646.8
# 10   November  2020   449.8
# 11   December  2020   258.8
# 12    January  2021   182.2
# 13   February  2021   352.4
# 14      March  2021   829.7
# 15      April  2021  1060.5
# 16        May  2021  1181.0
# 17       June  2021  1067.3
# 18       July  2021  1017.3
# 19     August  2021   917.4
# 20  September  2021   776.7
# 21    October  2021   649.6
# 22   November  2021   465.9
# 23   December  2021   258.5
# 24    January  2022   183.3
# 25   February  2022   367.5
# 26      March  2022   808.6
# 27      April  2022  1054.6
# 28        May  2022  1166.0
# 29       June  2022  1057.6
# 30       July  2022  1022.8
# 31     August  2022   919.0
# 32  September  2022   785.6
# 33    October  2022   698.5

# %%
df.describe(include=object)
# Out:
#           Month
# count        34
# unique       12
# top     January
# freq          3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Month   34 non-null     object
#  1   Year    34 non-null     int64
#  2   Amount  34 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 944.0+ bytes

# %% [markdown]
# ### <font color=blue>**Melting and Pivoting the dataset**</font>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %config InlineBackend.figure_format = "retina"
sns.set_context("talk")

import warnings
warnings.filterwarnings("ignore")

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
df= df.pivot(index="Year", columns="Month", values="Amount")
df
# Out:
# Month   April  August  December  February  January    July    June  March  \
# Year
# 2020    982.7   867.6     258.8     331.7    176.2   985.0  1031.0  725.7
# 2021   1060.5   917.4     258.5     352.4    182.2  1017.3  1067.3  829.7
# 2022   1054.6   919.0       NaN     367.5    183.3  1022.8  1057.6  808.6
#
# Month     May  November  October  September
# Year
# 2020   1115.3     449.8    646.8      725.4
# 2021   1181.0     465.9    649.6      776.7
# 2022   1166.0       NaN    698.5      785.6

# %%
print(df.isnull().values.any())
# Out:
# True

# %%
print(df.isnull().sum())
# Out:
# Month
# April        0
# August       0
# December     1
# February     0
# January      0
# July         0
# June         0
# March        0
# May          0
# November     1
# October      0
# September    0
# dtype: int64

# %% [markdown]
# <font color=red>There are 2 null values in the dataset because the data is still not available. These null values will be interpolated linearly based on the data available.</font>

# %%
df.interpolate(method='linear', direction = 'forward', 
inplace=True)

# %%
df.head()
# Out:
# Month   April  August  December  February  January    July    June  March  \
# Year
# 2020    982.7   867.6     258.8     331.7    176.2   985.0  1031.0  725.7
# 2021   1060.5   917.4     258.5     352.4    182.2  1017.3  1067.3  829.7
# 2022   1054.6   919.0     258.5     367.5    183.3  1022.8  1057.6  808.6
#
# Month     May  November  October  September
# Year
# 2020   1115.3     449.8    646.8      725.4
# 2021   1181.0     465.9    649.6      776.7
# 2022   1166.0     465.9    698.5      785.6

# %% [markdown]
# It can be observed that the interpolation value is the same value as with the previous year. (November and December 2021, 2022)

# %%
#reseting index
df1=df.reset_index()
df1
# Out:
# Month  Year   April  August  December  February  January    July    June  \
# 0      2020   982.7   867.6     258.8     331.7    176.2   985.0  1031.0
# 1      2021  1060.5   917.4     258.5     352.4    182.2  1017.3  1067.3
# 2      2022  1054.6   919.0     258.5     367.5    183.3  1022.8  1057.6
#
# Month  March     May  November  October  September
# 0      725.7  1115.3     449.8    646.8      725.4
# 1      829.7  1181.0     465.9    649.6      776.7
# 2      808.6  1166.0     465.9    698.5      785.6

# %%
df1.to_excel('Ireland_Milk_pivot.xlsx', index = False)

# %%
melted_ie= df1.melt(id_vars='Year',
         var_name='Month', 
         value_name='Amount')

# %%
melted_ie
# Out:
#     Year      Month  Amount
# 0   2020      April   982.7
# 1   2021      April  1060.5
# 2   2022      April  1054.6
# 3   2020     August   867.6
# 4   2021     August   917.4
# 5   2022     August   919.0
# 6   2020   December   258.8
# 7   2021   December   258.5
# 8   2022   December   258.5
# 9   2020   February   331.7
# 10  2021   February   352.4
# 11  2022   February   367.5
# 12  2020    January   176.2
# 13  2021    January   182.2
# 14  2022    January   183.3
# 15  2020       July   985.0
# 16  2021       July  1017.3
# 17  2022       July  1022.8
# 18  2020       June  1031.0
# 19  2021       June  1067.3
# 20  2022       June  1057.6
# 21  2020      March   725.7
# 22  2021      March   829.7
# 23  2022      March   808.6
# 24  2020        May  1115.3
# 25  2021        May  1181.0
# 26  2022        May  1166.0
# 27  2020   November   449.8
# 28  2021   November   465.9
# 29  2022   November   465.9
# 30  2020    October   646.8
# 31  2021    October   649.6
# 32  2022    October   698.5
# 33  2020  September   725.4
# 34  2021  September   776.7
# 35  2022  September   785.6

# %%
melted_ie.to_excel('Ireland_Milk_melted.xlsx', index = False)
